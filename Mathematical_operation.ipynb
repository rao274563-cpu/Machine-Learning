# %% [markdown]
# Get started

# %%
1+1
# Out:
# 2

# %%
print(2+3)
# Out:
# 5

# %%
print(8-2)
# Out:
# 6

# %%
print(10*5)
# Out:
# 50

# %%
print(7/2)
# Out:
# 3.5

# %%
print(5%2)
# Out:
# 1

# %%
print(2 ** 10)
# Out:
# 1024

# %%
name = "Sachin"
print("Hello, "+name)
# Out:
# Hello, Sachin

# %%
name = "Sachin"
fav = 47
print(name, "likes the number", fav)
print(fav, "square is", fav**2)
# Out:
# Sachin likes the number 47
# 47 square is 2209

# %% [markdown]
# log with base 10

# %% [markdown]
# Log with base 5

# %%
6**2, 5**3
# Out:
# (36, 125)

# %%
import math
math.log(5**6,5)
# Out:
# 6.000000000000001

# %%
math.log10(5)
# Out:
# 0.6989700043360189

# %%
# 5**x = 15625
x = math.log(15625,5)
print(f"X: ",x)
# Out:
# X:  6.000000000000001

# %% [markdown]
# log with base 2

# %%
math.log(2,2)
# Out:
# 1.0

# %%
math.log2(2)
# Out:
# 1.0

# %%
math.log(4,2) # log(4,2) and log(2**2,2) are equal
# Out:
# 2.0

# %%
math.log(8,2)
# Out:
# 3.0

# %% [markdown]
# log with base 3

# %%
math.log(3,3)
# Out:
# 1.0

# %%
math.log(127,3)
# Out:
# 4.40936910721378

# %%
math.log(3**4,3)
# Out:
# 4.0

# %% [markdown]
# Moving little ahead

# %%
lo, hi = .5, 1
mid = (lo+hi)/2
print("Mid: ",mid)
print(10**mid)
# Out:
# Mid:  0.75
# 5.623413251903491

# %%
print(10**2)
# Out:
# 100

# %%
lo, hi = .5, .75
mid = (lo+hi)/2
print("Mid: ",mid)
print(10**mid)
# Out:
# Mid:  0.625
# 4.216965034285822

# %%
lo, hi = .625, .75
mid = (lo+hi)/2
print("Mid: ",mid)
print(10**mid)
# Out:
# Mid:  0.6875
# 4.869675251658631

# %%
lo = mid
mid = (lo+hi)/2
print(mid)
print(10**mid)
# Out:
# 0.71875
# 5.232991146814947

# %%
lo = mid
print(f"lo:{lo}, hi:{hi}")
mid = (lo+hi)/2
print(mid)
print(10**mid)
# Out:
# lo:0.71875, hi:0.75
# 0.734375
# 5.424690937011326

# %%
hi = mid
mid = (lo+hi)/2
print(mid)
print(10**mid)
# Out:
# 0.7265625
# 5.327978945865641

# %%
hi = mid
mid = (lo+hi)/2
print(mid)
print(10**mid)
# Out:
# 0.72265625
# 5.280271456481318

# %%
if 10**mid > 5:
  hi = mid
else:
  lo = mid
hi = mid
print(f"lo:{lo}, hi:{hi}")
mid = (lo+hi)/2
print(mid)
print(10**mid)
# Out:
# lo:0.71875, hi:0.72265625
# 0.720703125
# 5.25657814405402

# %%
for i in range(5):
  if 10**mid > 5:
    hi = mid
  else:
    lo = mid
  print(f"lo:{lo}, hi:{hi}")
  mid = (lo+hi)/2
  print(mid)
  print(10**mid)
# Out:
# lo:0.71875, hi:0.720703125
# 0.7197265625
# 5.244771385901927
# lo:0.71875, hi:0.7197265625
# 0.71923828125
# 5.238877955201204
# lo:0.71875, hi:0.71923828125
# 0.718994140625
# 5.235933723684047
# lo:0.71875, hi:0.718994140625
# 0.7188720703125
# 5.234462228476621
# lo:0.71875, hi:0.7188720703125
# 0.71881103515625
# 5.23372663595983

# %%
#Function
123/10
# Out:
# 12.3

# %%
123/10/10
# Out:
# 1.23

# %%
123//10
# Out:
# 12

# %%
123%10
# Out:
# 3

# %%
lo = 1
hi = 10

# Pick a number between 1 and 10**10 and find it log.
math.log(27,10)
# Out:
# 1.4313637641589871

# %%
lo = 1
hi = 10
mid = (lo+hi/2)
print(mid)
print(10**mid)
# Out:
# 6.0
# 1000000.0

# %% [markdown]
# #Line Fitting & Curve Fitting

# %% [markdown]
# Write a python function with name f and x as argument and return y

# %%
#Equation of Strraight line (linear relationship)
def f(x):
  y = 4*x -1
  return y
f(2.5)
# Out:
# 9.0

# %%
f(2)
# Out:
# 7

# %%
f(0)
# Out:
# -1

# %%
def f(x):
  y = 4*x + 1
  return y
f(5)
# Out:
# 21

# %% [markdown]
# Two equation
#
# y1 = ax1 + b
#
# y2 = ax2 + b
#
# Using both equation:
#
# b = y1 - ax1
# a = (y2-y1)/(x2-x1)

# %%
#Now coding of two equation solution
def fit(x1, y1, x2, y2):
  a = (y2-y1)/(x2-x1)
  b = y1 - a*x1
  return a,b
f(1,3,2,7)
# Out:
# (4.0, -1.0)

# %%
def predict(a,b,x):
  return  a*x+b
predict(4,-1,3)
# Out:
# 11

# %%
def calculate_interest(p, r, t):

# %% [markdown]
# #Square Root

# %%
x = 10
x*x
# Out:
# 100

# %%
x**2
# Out:
# 100

# %%
x**.5
# Out:
# 3.1622776601683795

# %%
import math
math.sqrt(x)
# Out:
# 3.1622776601683795

# %%
import math
math.sqrt(25)
# Out:
# 5.0

# %% [markdown]
# square(3) = 9
# square(4) = 16
# square(5) = 25
#
# #What is the square root of 5 ?
#
# It is not a whole number but,
#
# 2*2 = 4 -> too low
#
# 3*3 = 9 -> too high
#
# So, the square root of 5 is between 2 and 3.

# %%
guess = 2.5 # Average of them
print(guess * guess)
# Out:
# 6.25

# %% [markdown]
# 6.25 is bigger than 5. Guess was too high!
#
# So, the answer is between 2 and 2.5

# %%
guess = 2.25
print(guess * guess)
# Out:
# 5.0625

# %% [markdown]
# 5.0625 is still too high!
#
# So, the anser is between 2 and 2.25

# %%
guess = 2.125
print(guess * guess)
# Out:
# 4.515625

# %% [markdown]
# 4.515625 is too low! answer is between 2.125 and 2.25.
#
# Our next guess will be between two numbers, let's call them lo and hi.
#
# Then calculate the midpoint (Average)

# %%
lo = 2
hi = 3
guess = (lo + hi)/2
print(f"guess: {guess}")
print(f"Guess square: {guess*guess}")
# Out:
# guess: 2.5
# Guess square: 6.25

# %% [markdown]
# guess: 2.5
# Guess square: 6.25
#
# Too high! So the answer is between lo and guess.
#
# Update hi = guess and compute a new midpoint.
#
# Can you automatically change the lo or hi depending on whether your guess
# squared was higher or lower than 5
#
# This is Python's if-else:

# %%
lo = 2
hi = 3
num = 5
guess = (lo + hi)/2

if guess*guess > num:
  hi = guess
else:
  lo = guess
print(f"new range: [{lo}, {hi}]")
# Out:
# new range: [2, 2.5]

# %% [markdown]
# Copying this block 20 times is tedious… to get the desired answer.
#
# Run your logic 20 times using a for loop:

# %%
lo = 2
hi = 3
num = 5

for i in range(20):
  guess = (lo + hi)/2
  if guess*guess > num:
    hi = guess
  else:
    lo = guess

print(f"sqrt({num}) = {guess}")
print(f"guess squared: {guess*guess}")
# Out:
# sqrt(5) = 2.236067771911621
# guess squared: 4.9999990805818015

# %%
lo = 2
hi = 3
num = input("Enter the number: ")
num = int(num)

for i in range(20):
  guess = (lo + hi)/2
  if guess*guess > num:
    hi = guess
  else:
    lo = guess

print(f"sqrt({num}) = {guess}")
print(f"guess squared: {guess*guess}")
# Out:
# Enter the number: 5
# sqrt(5) = 2.236067771911621
# guess squared: 4.9999990805818015

# %%
import math
print(f"Your answer: {guess}")
print(f"math.sqrt(5): ", math.sqrt(5)) #Python's built-in function
# Out:
# Your answer: 2.236067771911621
# math.sqrt(5):  2.23606797749979

# %% [markdown]
# #Square root of 10
# The answer is between 3*3 = 9 and 4 * 4 = 16

# %%
def mysqrt(nums, lo, hi, iterations):
  for i in range(iterations):
    guess = (lo + hi)/2
    if guess*guess > nums:
      hi = guess
    else:
      lo = guess
  return guess
result = mysqrt(10, 3, 4, 20)
print(f"sqrt(10)", result)
# Out:
# sqrt(10) 3.162278175354004

# %% [markdown]
# #Cuberoot
# Cuberoot of 33
#
# Answeer is between 3 and 4

# %%
def mycuberoot(num, lo, hi, iterations):
  for i in range(iterations):
    guess = (lo + hi)/2
    if guess*guess*guess > num:
      hi = guess
    else:
      lo = guess
  return guess
result = mycuberoot(33, 3, 4, 20)
print(f"cuberoot(33))", result)
# Out:
# cuberoot(33)) 3.207533836364746

# %% [markdown]
# #Fourthroot
#
# Fouthroot of 105
#
# Answer is between 3 and 4

# %%
def mycuberoot(num, lo, hi, iterations):
  for i in range(iterations):
    guess = (lo + hi)/2
    if guess**4 > num:
      hi = guess
    else:
      lo = guess
  return guess
result = mycuberoot(105, 3, 4, 20)
print(f"forthroot(105))", result)
# Out:
# forthroot(105)) 3.201085090637207

# %% [markdown]
# #nthroot
#
# let find the 5th root of 32.
# As we know the answer is 2

# %%
def mycuberoot(num, n, lo, hi, iterations):
  for i in range(iterations):
    guess = (lo + hi)/2
    if guess**n > num:
      hi = guess
    else:
      lo = guess
  return guess
result = mycuberoot(32,5, 1, 2, 20)
print(f"forthroot(105))", result)
# Out:
# forthroot(105)) 1.9999990463256836

# %% [markdown]
# #Logerithmic

# %%
# base 10
# log(1) -> 0
# log(10) -> 1
# log(100) -> 2
# log(1000) -> 3
# log(10000) -> 4
# .
# .
# .
# log(10**n) -> n

# Log is basically number of zeros

# antilog(2) -> 10**2 = 100

# %% [markdown]
# What is log(500)
#
# 10^2 = 100 (very small)
# 10^3 = 1000(too big)
#
# So log(500) is between 2 and 3
#
# Just take a guess

# %%
guess = 2.5
print(10**guess)
# Out:
# 316.22776601683796

# %% [markdown]
# 316.22776601683796 less than 500, the guess was too low.
#
# so, the answer is between 2.5 and 3

# %%
guess = 2.75
print(10**guess)
# Out:
# 562.341325190349

# %% [markdown]
# 562.341325190349 too high the answer is between 2.5 and 2.75

# %%
guess = 2.625
print(10**guess)
# Out:
# 421.6965034285823

# %% [markdown]
# 421.6965034285823 Too low! Answer is between 2.625 and 2.75.

# %%
lo = 2
hi = 3
guess = (lo + hi)/2
print(f"guess: {guess}")
print(f"Guess square: {10**guess}")
# Out:
# guess: 2.5
# Guess square: 316.22776601683796

# %% [markdown]
# automatically change lo or hi depending on whether 10**guess was higher or lower than 500?
#
# This is Python’s if-else:

# %%
lo = 2
hi = 3
value = 500
guess = (lo + hi)/2

if 10**guess > value:
  hi = guess
else:
  lo = guess
print(f"New range: [{lo}, {hi}]")
# Out:
# New range: [2.5, 3]

# %%
lo = 2
hi = 3
value = 500

for i in range(20):
  guess = (lo + hi)/2
  if 10**guess > value:
    hi = guess
  else:
    lo = guess
print(f"log({value}): {guess}")
print(f"10**guess: {10**guess}")
# Out:
# log(500): 2.698969841003418
# 10**guess: 499.9998119564294

# %% [markdown]
# Python Built-in function

# %%
import math
print(f"Guess:           {guess}")
print(f"math.log10(500): {math.log10(500)}")
# Out:
# Guess:           2.698969841003418
# math.log10(500): 2.6989700043360187

# %%
# log(something) -> 5
# what is something = ?
# something -> 10**5 = 100000

# %% [markdown]
# My built-in log function

# %%
def mylog(value, base, lo, hi, iteration):
  for i in range(iteration):
    guess = (lo + hi)/2
    if base**guess > value:
      hi = guess
    else:
      lo = guess
  return guess
result = mylog(500, 10, 2, 3, 20)
print(result)
# Out:
# 2.698969841003418

# %%
import math

result = mylog(500, 10, 2, 3, 20)
print(f"result:     {result}")
print(f"math.log10: {math.log10(500)}")
# Out:
# result:     2.698969841003418
# math.log10: 2.6989700043360187

# %%
import math

result = mylog(1000, 10, 2, 4, 20)
print(f"result:     {result}")
print(f"math.log10: {math.log10(1000)}")
# Out:
# result:     3.000001907348633
# math.log10: 3.0

# %%
import math

result = mylog(8, 2, 2, 4, 20)
print(f"result:     {result}")
print(f"math.log10: {math.log2(8)}")
# Out:
# result:     3.000001907348633
# math.log10: 3.0

# %%
import math

result = mylog(27, 3, 2, 4, 20)
print(f"result:     {result}")
print(f"math.log10: {math.log2(8)}")
# Out:
# result:     3.000001907348633
# math.log10: 3.0

# %%
import math
def log_base(value, base):
    return math.log10(value) / math.log10(base)
print(log_base(500,10))
# Out:
# 2.6989700043360187

# %%
from math import *
# We are using 10 as the base
log(100,10)

m = log(10**6, 10)
print(f"log(10**6, 10): ",m)

# %% [markdown]
# #Expressions and Functions

# %%
# Variables — a name that holds a value
x = 42
name = "hello"

# Arithmetic: +  -  *  /  //  %  **
result = 3 + 4 * 2      # 11 (multiplication first)
print("3 + 4 * 2: ",result)

remainder = 17 % 5       # 2
print("17 % 5: ",remainder)

power = 2 ** 10          # 1024
print("2 ** 10: ", power)

int_div = 7 // 2         # 3 (drops the decimal)
print("7 // 2: ",int_div)
# Out:
# 3 + 4 * 2:  11
# 17 % 5:  2
# 2 ** 10:  1024
# 7 // 2:  3

# %%
# Functions — reusable blocks of code
def add(a, b):
    return a + b         # indentation matters!

add(3, 5)                # 8
# Out:
# 8

# %%
# Calling a function inside a function
def hypotenuse(base, height):
    return (base**2 + height**2) ** 0.5

# Printing output
print("answer:", hypotenuse(3, 5))
# Out:
# answer: 5.830951894845301

# %% [markdown]
# Extract the last digits of the following:
#
# 2478, 7, 100, 0

# %%
print(f"last digit of 2478: {2478%10}")
print(f"last digit of 7: {7%10}")
print(f"last digit of 100: {100%10}")
print(f"last digit of 0: {0%10}")
# Out:
# last digit of 2478: 8
# last digit of 7: 7
# last digit of 100: 0
# last digit of 0: 0

# %% [markdown]
# last digits of the following:
#
# 2478, 7, 100

# %%
print(f"last digit of 2478: {2478 // 10}")
print(f"last digit of 7: {7 // 10}")
print(f"last digit of 100: {100 // 10}")
# Out:
# last digit of 2478: 247
# last digit of 7: 0
# last digit of 100: 10

# %%
n = input("Enter a number: ")
n = int(n)
def remove_last_digit(n):
  return n // 10
print("droped digit number:",remove_last_digit(n))
# Out:
# Enter a number: 2478
# droped digit number: (247, 8)

# %%
n = input("Enter a number: ")
n = int(n)
removed_last_digit = n // 10
last_digit = n%10
def check_roundtrip(n):
  if removed_last_digit * 10 + last_digit == n:
    return True
  else:
    return False
print(f"Input number: {n} and Checked number are equal: {check_roundtrip(n)}")
# Out:
# Enter a number: 100
# Input number: 100 and Checked number are equal: True

# %% [markdown]
# #Simple Interest
#
# Interest = (Principal * Rate * Time) / 100
#
# where:
#
# Principal — the amount deposited or borrowed
#
# Rate — the interest rate per year, as a percentage
#
# Time — the number of years
#
# If you deposit 1000 at a rate of 5% for 2 years, what's the interest, by hand?

# %%
def calculate_interest(p, r, t):
  return (p * r* t)/100

print("Clacualted interest: ",calculate_interest(1000, 5, 2))
print(f"If time=0 then Calculated interst: ", calculate_interest(1000,5,0))
# Out:
# Clacualted interest:  100.0
# If time=0 then Calculated interst:  0.0

# %%
def calculate_interest(principal, rate, time):
  return (principal * rate * time)/100
print(f"Calculated Interest: {calculate_interest(1500, 4.3, 3)}")
print(f"Calculated Interest: {calculate_interest(500, 10, 0)}")
# Out:
# Calculated Interest: 193.5
# Calculated Interest: 0.0

# %% [markdown]
# #The Hypotenuse
#
# In mathematics : hypotenuse^2 = (base^2) + (height)^1/2
#
# hypotenuse^2 = ( (base^2) + (height)^2 ) ^ 1/2
#
# hypotenuse**2 = (base ** 2 + height ** 2) ** 0.5
#
# In python : hyp = sqrt(base ** 2 + height ** 2)

# %%
def cal_hypotenuse(base, height):
  return (base**2 + height**2) ** 0.5
print(f"Hypotenuse: {cal_hypotenuse(4,5)}")
print(f"Hypotenuse with base 5 and height 12: {cal_hypotenuse(5,12)}")
print(f"Hypotenuse with base 0 and height 0: {cal_hypotenuse(0,0)}")
# Out:
# Hypotenuse: 6.4031242374328485
# Hypotenuse with base 5 and height 12: 13.0
# Hypotenuse with base 0 and height 0: 0.0

# %%
import math
result = math.sqrt(5**2 + 12**2)
print(result)
# Out:
# 13.0

# %% [markdown]
# #Distance between Two points
#
# Distance between two points = ((x2-x1)^2 + (y2-y1)^2) ^ 1/2
#
# It is kind of hypotenuse where
#
# base = x2-x1 (horizontal separation)
# height = y2-y1 (vertical separation)
#
# In Python
#
# find_distance_2d(x1, y1, x2, y2) = sqrt((x2 - x1)**2 + (y2 - y1)**2)

# %%
def find_distance_2pts(x1, y1, x2, y2):
  return sqrt((x2 - x1)**2 + (y2- y1)**2)

print(find_distance_2pts(0, 0, 3, 4))
print(find_distance_2pts(1, 2, 4, 6))
# Out:
# 5.0
# 5.0

# %% [markdown]
# Distance between 3 points

# %%
def find_distance_3pts(x1, y1, z1, x2, y2, z2):
  return sqrt((x2-x1)**2 + (y2-y1)**2 + (z2-z1)**2)
print(find_distance_3pts(0, 0, 0, 1, 1, 1))
print(find_distance_3pts(2, 3, 5, 2, 3, 5))
print(find_distance_3pts(1, 2, 3, 4, 6, 9))
# Out:
# 1.7320508075688772
# 0.0
# 7.810249675906654

# %% [markdown]
# #Manhattan Distance
#
# Distance from (2, 3) to (5, 1)
#
# dist = |x2 - x1| + |y2 - y1|
#
# From (2, 3) to (5, 1): horizontally |5 - 2| = 3, vertically |1 - 3| = 2, total = 3 + 2 = 5.
#
# dist = abs(x2-x1) + abs(y2-y1)

# %%
def manhattan_dist(x1, y1, x2, y2):
  return abs(x2 - x1) + abs(y2 - y1)
print(manhattan_dist(2,3,5,1))
# Out:
# 5

# %%
def calc_manhattan_dist(x1, y1, x2, y2):
  return abs(x2 - x1) + abs(y2 - y1)

print(f"Manhattan Distance (2, 3, 5, 1): {calc_manhattan_dist(2, 3, 5, 1)} Unit")
# Out:
# Manhattan Distance (2, 3, 5, 1): 5 Unit

# %%
def find_manhatt_dist(x1, y1, x2, y2):
  return abs(x2- x1) + abs(y2 - y1)

print(f"Manahhtan Distance (0, 0, 0, 0) is {find_manhatt_dist(0, 0, 0, 0)} Unit")
# Out:
# Manahhtan Distance (0, 0, 0, 0) is 0 Unit

# %%
def manhattan_distance(x1, y1, x2, y2):
  return abs(x2 - x1) + abs(y2 - y1)

print(f"Manhattan Distance for points (-1, -1, 1, 1) is {manhattan_distance(-1, -1, 1, 1)} Unit")
# Out:
# Manhattan Distance for points (-1, -1, 1, 1) is 4 Unit

# %% [markdown]
# #Predicting `y` from `x`
#
# A straight line in 2D can be written as:
#
# y = m * x + c {m is the slop (steepness) and c is the intercept(where line crosses the y-axis}

# %%
def pred_y(m, c, x):
  return m * x + c
print(f"y : {pred_y(2, 3, 4)}")
# Out:
# y : 11

# %%
import matplotlib.pyplot as plt

def plot_line(m, c, x_range=(-10, 10), extra_points=None, title=None):
    n = 100
    xs = [x_range[0] + i * (x_range[1] - x_range[0]) / n for i in range(n + 1)]
    ys = [pred_y(m, c, x) for x in xs]

    plt.figure(figsize=(2, 3))
    plt.plot(xs, ys, 'b-', label=f"y = {m}x + {c}")
    if extra_points:
        px = [p[0] for p in extra_points]
        py = [p[1] for p in extra_points]
        plt.scatter(px, py, color='red', zorder=5, label='points')
    plt.axhline(0, color='gray', linewidth=0.5)
    plt.axvline(0, color='gray', linewidth=0.5)
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title(title or f"y = {m}x + {c}")
    plt.legend()
    plt.grid(True)
    plt.show()

# %% [markdown]
# Need to watch lecture on the below concept
# #Expressions and Functions

# %%
plot_line(2, 3)

# %% [markdown]
# Predicting Slope 'm' and Intercept 'c'

# %%
def fit(x1, y1, x2, y2):
  m = (y2 - y1)/(x2 - x1)
  c = y1 - m * x1
  return (m, c)
fit(1, 2, 3, 6)
# Out:
# (2.0, 0.0)

# %%
def fit(x1, y1, x2, y2):
  m = (y2 - y1) / (x2 - x1)
  c = y1 - m * x1
  return (m,c)

fit(0, 5, 2, 9)
# Out:
# (2.0, 5.0)

# %%
m, c = fit(1, 2, 3, 6)
print(f"m: {m}, c: {c}")

print(f"Predicy y at x=1, {pred_y(m,c,1)}")
print(f"Predicy y at x=3, {pred_y(m,c,3)}")
print(f"Predicy y at x=5, {pred_y(m,c,5)}")
# Out:
# m: 2.0, c: 0.0
# Predicy y at x=1, 2.0
# Predicy y at x=3, 6.0
# Predicy y at x=5, 10.0

# %%
plot_line(m, c, extra_points=[(1, 2), (3, 6)])

# %% [markdown]
# #Rate of Change, Without Calculus
#
# This is called the forward difference method:
#
# f'(x) = ( f(x + h) - f(x) ) / h
#
# where h is a small number

# %%
def square(x):
    return x * x

def approx_derivative(func, x, h):
  return ( func(x + h) - func(x) ) / h

approx_derivative(square, 3, 0.0001)
# Out:
# 6.000100000012054

# %% [markdown]
# # TODO: Test all three derivative
# A. (f(x+h) - f(x))/h
#
# B. (f(x) - f(x-h))/h
#
# C. (f(x+h) - f(x-h))/h

# %%
def diff(myf, x1, x2):
  h = 1e-10
  y = myf(x1, x2)
  dy_dx1 = ((myf(x1+h) + h, x2) - y)/h
  dy_dx2 = (myf())

# %% [markdown]
# #If-else Logic
#
# This chapter uses if/elif/else to make decisions and comparisons to test conditions.

# %%
# Comparison operators: ==  !=  <  >  <=  >=
x = 7
x > 5           # True
x == 7          # True
x != 3          # True

#if/else/elif

if x > 10:
  print("Big")
elif x > 5:
  print("Medium")
else:
  print("Small")

#Combining conditions: and, or, not
if x > 0 and x <100:
  print("in range")
# Out:
# Medium
# in range

# %%
#Returning different values from a function
n = input("Enter a number: ")
n = int(n)
def classify(n):
  if n > 0:
    return "Positive"
  elif n < 0:
    return "Negative"
  else:
    return "Zero"
classify(n)
# Out:
# Enter a number: 50
# 'Positive'

# %%
import random
import matplotlib.pyplot as plt

random.random()
# Out:
# 0.4433618031698855

# %%
random.random()*6   # return all infinite values between 0 to 5
# Out:
# 3.4875160149012077

# %%
int(random.random() * 6) # return values : 0, 1, 2, 3, 4, 5
# Out:
# 2

# %% [markdown]
# A Random Die Roll

# %%
int(random.random() * 6) + 1 # return values : 1, 2, 3, 4, 5, 6

# %% [markdown]
# roll_die code

# %%
def roll_die():
  return int(random.random() * 6) + 1

for i in range(20):
  print(roll_die(), end=" ")
# Out:
# 1 6 1 3 6 6 2 6 2 6 6 5 5 2 6 3 3 6 5 4

# %% [markdown]
# Code to predict the head pr tail

# %%
def coin_toss():
  if random.random() < 0.5:
    return "Heads"
  else:
    return "Tails"

print([coin_toss() for _ in range(20)])

heads_count = 0
for _ in range(1000):
  if coin_toss() == "Heads":
    heads_count = heads_count + 1
print(f"Heads: {heads_count} / 1000")
# Out:
# ['Heads', 'Tails', 'Heads', 'Heads', 'Heads', 'Heads', 'Heads', 'Tails', 'Tails', 'Tails', 'Heads', 'Heads', 'Heads', 'Heads', 'Tails', 'Tails', 'Tails', 'Heads', 'Tails', 'Heads']
# Heads: 481 / 1000

# %%
def classify_roll(n):
  if n <= 2:
    return "Low"
  elif n <= 4:
    return "Medium"
  else:
    return "High"

for _ in range(20):
  n = roll_die()
  print(f"{n} -> {classify_roll(n)}")
# Out:
# 3 -> Medium
# 1 -> Low
# 6 -> High
# 4 -> Medium
# 6 -> High
# 5 -> High
# 3 -> Medium
# 2 -> Low
# 4 -> Medium
# 1 -> Low
# 2 -> Low
# 3 -> Medium
# 4 -> Medium
# 6 -> High
# 6 -> High
# 4 -> Medium
# 1 -> Low
# 6 -> High
# 5 -> High
# 5 -> High

# %% [markdown]
# Closer Point (Comparision between two Points)

# %%
def closer_point(p, a, b):
  p_to_a = (p[0] - a[0])**2 + (p[1] + a[1])**2
  p_to_b = (p[0] - b[0])**2 + (p[1] + b[1])**2
  if p_to_a < p_to_b:
    return "A"
  else:
    return "B"

closer_point(p=(1, 2), a=(0, 0), b=(5, 5))
# Out:
# 'A'

# %%
def closer_point(p, a, b):
  p_to_a = (p[0] - a[0])**2 + (p[1] + a[1])**2
  p_to_b = (p[0] - b[0])**2 + (p[1] + b[1])**2
  if p_to_a < p_to_b:
    return "A"
  elif p_to_a > p_to_b:
    return "B"
  else:
    return "Equal"

closer_point((1, 2), (0, 0), (5, 5))
# Out:
# 'A'

# %%
closer_point(p=(4, 4), a=(0, 0), b=(8, 8)) #Wrong answer
# Out:
# 'A'

# %%
closer_point((7, 3), (2, 3), (10, 3))
# Out:
# 'B'

# %%
print(closer_point((0, 0), (-10, 0), (10, 0)))
# Out:
# Equal

# %%
print(closer_point((3, 0), (0, 0), (10, 10)))
# Out:
# A

# %% [markdown]
# is_point_on_line_1d

# %%
def is_point_on_line_1d(a, b, p):
    if min(a,b) <= p <= max(a,b):
        return True
    else:
        return False
print(is_point_on_line_1d(2, 5, 4))
# Out:
# True

# %%
def is_point_on_line_1d(a,b,p):
    if min(a, b) <= p <= max(a, b):
        return True
    else:
        return False

print(is_point_on_line_1d(5, 2, 3))
# Out:
# True

# %%
def is_point_on_line_1d(a,b,p):
    if min(a, b) <= p <= max(a, b):
        return True
    else:
        return False

print(is_point_on_line_1d(4, 4, 4))
# Out:
# True

# %%
def is_point_on_line_1d(a, b, p):
    if min(a, b) <= p <= max(a, b):
        return True
    else:
        return False
print(is_point_on_line_1d(4, 4, 5))
# Out:
# False

# %% [markdown]
# Test with Negative Numbers

# %%
def is_point_on_line_1d(a, b, p):
    if min(a, b) <= p <= max(a, b):
        return True
    else:
        return False

print(is_point_on_line_1d(-5, -2, -3))
# Out:
# True

# %%
def is_point_on_line_1d(a, b, p):
    if min(a, b) <= p <= max(a, b):
        return True
    else:
        return False
    
print(is_point_on_line_1d(-5, -2, -6))
# Out:
# False

# %%
print(is_point_on_line_1d(-2, -5, -4))
# Out:
# True

# %%
is_point_on_line_1d(-1, 3, 0)
# Out:
# True

# %%
print(is_point_on_line_1d(-5, -2, -3))
# Out:
# True

# %%
print(is_point_on_line_1d(-5, -2, -6))
# Out:
# False

# %%
print(is_point_on_line_1d(-2, -5, -4))   # True
# Out:
# True

# %%
print(is_point_on_line_1d(-1, 3, 0))
# Out:
# True

# %%
def are_lines_touching_or_overlapping(start1, end1, start2, end2):
    lo1, hi1 = min(start1, end1), max(start1, end1)
    lo2, hi2 = min(start2, end2), max(start2, end2)
    if (hi1 >= lo2 and lo1 <= hi2) and not (hi1 < lo2 or lo1 > hi2):
        return True
    else:
        return False

print(are_lines_touching_or_overlapping(1, 2, 3, 4))
# Out:
# False

# %%
are_lines_touching_or_overlapping(1, 4, 3, 6)
# Out:
# True

# %% [markdown]
# Test with Negative and Reversed Inputs

# %%
def are_lines_touching_or_overlapping(start1, end1, start2, end2):
    hi1, lo1 = max(start1, end1), min(start1, end1)
    hi2, lo2 = max(start2, end2), min(start2, end2)
    
    if (hi1 >= lo2 and lo1 <= hi2) and not(hi1 < lo2 or lo1 > hi2):
        return True
    
print(are_lines_touching_or_overlapping(-3, 1, 0, 4))
# Out:
# True

# %%
def are_lines_touching_or_overlapping(start1, end1, start2, end2):
    hi1, lo1 = max(start1, end1), min(start1, end1)
    hi2, lo2 = max(start2, end2), min(start2, end2)
    
    if (hi1 >= lo2 and lo1 <= hi2) and not(hi1 < lo2 or lo1 > hi2):
        return True
    else:
        return False

print(are_lines_touching_or_overlapping(-10, -6, -5, -1))
# Out:
# False
